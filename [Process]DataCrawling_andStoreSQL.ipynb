# %% [markdown]
# # import libs and database connect

# %%
import os
import requests
import zipfile
from io import BytesIO
from datetime import datetime, timedelta
from datetime import date, timedelta
import sqlite3
import pandas as pd

# %%
# Connect to SQLite database
conn = sqlite3.connect("nem_data.db")
cursor = conn.cursor()

# %% [markdown]
# # data crawling

# %%
# Define the date range
start_date = date(2019, 1, 1)
end_date = date(2025, 1, 1)

# Base URL
base_url = "https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/{year}/MMSDM_{year}_{month:02d}/MMSDM_Historical_Data_SQLLoader/DATA/"

# File name patterns
file_patterns = [
    "PUBLIC_DVD_DUDETAILSUMMARY_{year}{month:02d}010000.zip",
    "PUBLIC_DVD_DISPATCH_UNIT_SCADA_{year}{month:02d}010000.zip"
]

# Output directories
download_dir = "downloaded_zips"
extract_dir = "extracted_csv"

# Create directories if they don't exist
os.makedirs(download_dir, exist_ok=True)
os.makedirs(extract_dir, exist_ok=True)

# %%
# Iterate through each month in the date range
current_date = start_date
while current_date <= end_date:
    year = current_date.year
    month = current_date.month

    # Construct the base URL for the given year and month
    url = base_url.format(year=year, month=month)

    for pattern in file_patterns:
        file_name = pattern.format(year=year, month=month)
        file_url = url + file_name
        zip_path = os.path.join(download_dir, file_name)

        try:
            # Download the ZIP file
            print(f"Downloading: {file_url}")
            response = requests.get(file_url, stream=True)
            if response.status_code == 200:
                with open(zip_path, "wb") as file:
                    file.write(response.content)
                print(f"Downloaded: {file_name}")

                # Extract the ZIP file
                with zipfile.ZipFile(zip_path, "r") as zip_ref:
                    zip_ref.extractall(extract_dir)
                print(f"Extracted: {file_name} to {extract_dir}")

            else:
                print(f"File not found: {file_url}")

        except Exception as e:
            print(f"Error downloading {file_name}: {e}")

    # Move to the next month
    current_date += timedelta(days=32)
    current_date = current_date.replace(day=1)
# Out:
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202408010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202408010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202408010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202408010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202409010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202409010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202409010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202409010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202410010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202410010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202410010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202410010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202411010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202411010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202411010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202411010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202412010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202412010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202412010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202412010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202501010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DUDETAILSUMMARY_202501010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202501010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202501010000.zip

# %% [markdown]
# ## for demand data

# %%
# Define the date range
start_date = date(2024, 8, 1)
end_date = date(2025, 2, 1)

# Base URL
base_url = "https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/{year}/MMSDM_{year}_{month:02d}/MMSDM_Historical_Data_SQLLoader/DATA/"

# File name patterns
file_patterns = [
    "PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#{year}{month:02d}010000.zip",
    "PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#{year}{month:02d}010000.zip"
]

# Output directories
download_dir = "downloaded_zips_demand"
extract_dir = "extracted_csv_demand"

# Create directories if they don't exist
os.makedirs(download_dir, exist_ok=True)
os.makedirs(extract_dir, exist_ok=True)

# %%
# Iterate through each month in the date range
current_date = start_date
while current_date <= end_date:
    year = current_date.year
    month = current_date.month

    # Construct the base URL for the given year and month
    url = base_url.format(year=year, month=month)

    for pattern in file_patterns:
        file_name = pattern.format(year=year, month=month)
        file_url = url + file_name
        zip_path = os.path.join(download_dir, file_name)

        try:
            # Download the ZIP file
            print(f"Downloading: {file_url}")
            response = requests.get(file_url, stream=True)
            if response.status_code == 200:
                with open(zip_path, "wb") as file:
                    file.write(response.content)
                print(f"Downloaded: {file_name}")

                # Extract the ZIP file
                with zipfile.ZipFile(zip_path, "r") as zip_ref:
                    zip_ref.extractall(extract_dir)
                print(f"Extracted: {file_name} to {extract_dir}")

            else:
                print(f"File not found: {file_url}")

        except Exception as e:
            print(f"Error downloading {file_name}: {e}")

    # Move to the next month
    current_date += timedelta(days=32)
    current_date = current_date.replace(day=1)
# Out:
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202408010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202408010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202408010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_08/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202408010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202409010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202409010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202409010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_09/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202409010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202410010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202410010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202410010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_10/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202410010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202411010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202411010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202411010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_11/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202411010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202412010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202412010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202412010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2024/MMSDM_2024_12/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202412010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202501010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202501010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202501010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_01/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202501010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_02/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202502010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_02/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALACTUAL#FILE01#202502010000.zip
# Downloading: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_02/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202502010000.zip
# File not found: https://nemweb.com.au/Data_Archive/Wholesale_Electricity/MMSDM/2025/MMSDM_2025_02/MMSDM_Historical_Data_SQLLoader/DATA/PUBLIC_ARCHIVE#DEMANDOPERATIONALFORECAST#FILE01#202502010000.zip

# %% [markdown]
# # organise to SQLite

# %% [markdown]
# ## create tables

# %%
# !rm nem_data.db
# Connect to SQLite database
conn = sqlite3.connect("nem_data.db")
cursor = conn.cursor()

# Create DUDETAILSUMMARY table
cursor.execute("""
CREATE TABLE IF NOT EXISTS DUDETAILSUMMARY (
    I TEXT,
    PARTICIPANT_REGISTRATION TEXT,
    DUDETAILSUMMARY TEXT,
    "7" REAL,
    DUID TEXT PRIMARY KEY,
    START_DATE TEXT,
    END_DATE TEXT,
    DISPATCHTYPE TEXT,
    CONNECTIONPOINTID TEXT,
    REGIONID TEXT,
    STATIONID TEXT,
    PARTICIPANTID TEXT,
    LASTCHANGED TEXT,
    TRANSMISSIONLOSSFACTOR REAL,
    STARTTYPE TEXT,
    DISTRIBUTIONLOSSFACTOR REAL,
    MINIMUM_ENERGY_PRICE REAL,
    MAXIMUM_ENERGY_PRICE REAL,
    SCHEDULE_TYPE TEXT,
    MIN_RAMP_RATE_UP REAL,
    MIN_RAMP_RATE_DOWN REAL,
    MAX_RAMP_RATE_UP REAL,
    MAX_RAMP_RATE_DOWN REAL,
    IS_AGGREGATED REAL,
    DISPATCHSUBTYPE TEXT,
    ADG_ID TEXT,
    LOAD_MINIMUM_ENERGY_PRICE REAL,
    LOAD_MAXIMUM_ENERGY_PRICE REAL,
    LOAD_MIN_RAMP_RATE_UP REAL,
    LOAD_MIN_RAMP_RATE_DOWN REAL,
    LOAD_MAX_RAMP_RATE_UP REAL,
    LOAD_MAX_RAMP_RATE_DOWN REAL,
    SECONDARY_TLF REAL
);
""")

# Create DISPATCH_UNIT_SCADA table
cursor.execute("""
CREATE TABLE IF NOT EXISTS DISPATCH_UNIT_SCADA (
    I TEXT,
    DISPATCH TEXT,
    UNIT_SCADA TEXT,
    "1" REAL,
    SETTLEMENTDATE TEXT,
    DUID TEXT,
    SCADAVALUE REAL,
    LASTCHANGED TEXT,
    FOREIGN KEY (DUID) REFERENCES DUDETAILSUMMARY(DUID)
);
""")

conn.commit()

# %% [markdown]
# ## load data and import to database

# %%
# Start looping from Jan 2019 to Jan 2025
start_date = date(2019, 1, 1)
end_date = date(2025, 1, 1)
current_date = start_date

while current_date <= end_date:
    year_month = current_date.strftime("%Y%m")

    # Determine the file names based on the current date
    if current_date >= date(2024, 8, 1):  # After Aug 2024
        du_details_csv = f"extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#{year_month}010000.CSV"
        scada_csv = f"extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#{year_month}010000.CSV"
    else:  # Before Aug 2024
        du_details_csv = f"extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_{year_month}010000.CSV"
        scada_csv = f"extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_{year_month}010000.CSV"

    # Process DUDETAILSUMMARY (if file exists)
    try:
        if os.path.exists(du_details_csv):
            df_du = pd.read_csv(du_details_csv, skiprows=1)  # Skip first row
            df_du.to_sql("DUDETAILSUMMARY", conn, if_exists="replace", index=False)
            print(f"✅ Inserted {len(df_du)} rows into DUDETAILSUMMARY from {du_details_csv}")
    except Exception as e:
        print(f"❌❌❌ ERROR with {du_details_csv}: {e}")
        current_date = current_date + timedelta(days=32)
        current_date = current_date.replace(day=1)
        continue

    # Process DISPATCH_UNIT_SCADA (if file exists)
    try:
        if os.path.exists(scada_csv):
            df_scada = pd.read_csv(scada_csv, skiprows=1)  # Skip first row
            df_scada.to_sql("DISPATCH_UNIT_SCADA", conn, if_exists="append", index=False)
            print(f"✅ Inserted {len(df_scada)} rows into DISPATCH_UNIT_SCADA from {scada_csv}")
            print("*" * 20)
    except Exception as e:
        print(f"❌❌❌ ERROR with {scada_csv}: {e}")
        current_date = current_date + timedelta(days=32)
        current_date = current_date.replace(day=1)
        continue

    # Move to the next month
    current_date = current_date + timedelta(days=32)
    current_date = current_date.replace(day=1)

# Close connection
conn.commit()
conn.close()

print("🎉 Data import completed!")
# Out:
# ✅ Inserted 8977 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201901010000.CSV
# ✅ Inserted 2831589 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201901010000.CSV
# ********************
# ✅ Inserted 8978 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201902010000.CSV
# ✅ Inserted 2577552 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201902010000.CSV
# ********************
# ✅ Inserted 8984 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201903010000.CSV
# ✅ Inserted 2869806 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201903010000.CSV
# ********************
# ✅ Inserted 8985 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201904010000.CSV
# ✅ Inserted 2796195 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201904010000.CSV
# ********************
# ✅ Inserted 8994 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201905010000.CSV
# ✅ Inserted 2901604 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201905010000.CSV
# ********************
# ✅ Inserted 9494 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201906010000.CSV
# ✅ Inserted 2838273 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201906010000.CSV
# ********************
# ✅ Inserted 9496 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201907010000.CSV
# ✅ Inserted 2945783 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201907010000.CSV
# ********************
# ✅ Inserted 9499 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201908010000.CSV
# ✅ Inserted 2954559 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201908010000.CSV
# ********************
# ✅ Inserted 9506 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201909010000.CSV
# ✅ Inserted 2867042 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201909010000.CSV
# ********************
# ✅ Inserted 9522 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201910010000.CSV
# ✅ Inserted 2981574 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201910010000.CSV
# ********************
# ✅ Inserted 9527 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201911010000.CSV
# ✅ Inserted 2893667 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201911010000.CSV
# ********************
# ✅ Inserted 9532 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_201912010000.CSV
# ✅ Inserted 3008860 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_201912010000.CSV
# ********************
# ✅ Inserted 9542 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202001010000.CSV
# ✅ Inserted 3031454 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202001010000.CSV
# ********************
# ✅ Inserted 9553 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202002010000.CSV
# ✅ Inserted 2840729 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202002010000.CSV
# ********************
# ✅ Inserted 9555 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202003010000.CSV
# ✅ Inserted 3067033 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202003010000.CSV
# ********************
# ✅ Inserted 9559 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202004010000.CSV
# ✅ Inserted 2988327 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202004010000.CSV
# ********************
# ✅ Inserted 9564 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202005010000.CSV
# ✅ Inserted 3112823 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202005010000.CSV
# ********************
# ✅ Inserted 10082 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202006010000.CSV
# ✅ Inserted 3023785 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202006010000.CSV
# ********************
# ✅ Inserted 10088 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202007010000.CSV
# ✅ Inserted 3132894 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202007010000.CSV
# ********************
# ✅ Inserted 10090 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202008010000.CSV
# ✅ Inserted 3136690 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202008010000.CSV
# ********************
# ✅ Inserted 10092 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202009010000.CSV
# ✅ Inserted 3054202 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202009010000.CSV
# ********************
# ✅ Inserted 10107 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202010010000.CSV
# ✅ Inserted 3152688 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202010010000.CSV
# ********************
# ✅ Inserted 10117 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202011010000.CSV
# ✅ Inserted 3093175 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202011010000.CSV
# ********************
# ✅ Inserted 10129 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202012010000.CSV
# ✅ Inserted 3248906 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202012010000.CSV
# ********************
# ✅ Inserted 10132 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202101010000.CSV
# ✅ Inserted 3266151 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202101010000.CSV
# ********************
# ✅ Inserted 10134 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202102010000.CSV
# ✅ Inserted 2979796 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202102010000.CSV
# ********************
# ✅ Inserted 10136 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202103010000.CSV
# ✅ Inserted 3305220 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202103010000.CSV
# ********************
# ✅ Inserted 10146 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202104010000.CSV
# ✅ Inserted 3210970 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202104010000.CSV
# ********************
# ✅ Inserted 10149 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202105010000.CSV
# ✅ Inserted 3341953 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202105010000.CSV
# ********************
# ✅ Inserted 10725 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202106010000.CSV
# ✅ Inserted 3262930 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202106010000.CSV
# ********************
# ✅ Inserted 10729 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202107010000.CSV
# ✅ Inserted 3445428 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202107010000.CSV
# ********************
# ✅ Inserted 10730 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202108010000.CSV
# ✅ Inserted 3478505 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202108010000.CSV
# ********************
# ✅ Inserted 10736 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202109010000.CSV
# ✅ Inserted 3368945 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202109010000.CSV
# ********************
# ✅ Inserted 10751 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202110010000.CSV
# ✅ Inserted 3488365 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202110010000.CSV
# ********************
# ✅ Inserted 10769 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202111010000.CSV
# ✅ Inserted 3433899 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202111010000.CSV
# ********************
# ✅ Inserted 10779 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202112010000.CSV
# ✅ Inserted 3578984 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202112010000.CSV
# ********************
# ✅ Inserted 10785 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202201010000.CSV
# ✅ Inserted 3605618 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202201010000.CSV
# ********************
# ✅ Inserted 10797 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202202010000.CSV
# ✅ Inserted 3279357 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202202010000.CSV
# ********************
# ✅ Inserted 10804 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202203010000.CSV
# ✅ Inserted 3682802 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202203010000.CSV
# ********************
# ✅ Inserted 10808 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202204010000.CSV
# ✅ Inserted 3595573 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202204010000.CSV
# ********************
# ✅ Inserted 10813 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202205010000.CSV
# ✅ Inserted 3727951 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202205010000.CSV
# ********************
# ✅ Inserted 11433 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202206010000.CSV
# ✅ Inserted 3634084 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202206010000.CSV
# ********************
# ✅ Inserted 11438 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202207010000.CSV
# ✅ Inserted 3794308 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202207010000.CSV
# ********************
# ✅ Inserted 11443 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202208010000.CSV
# ✅ Inserted 3817429 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202208010000.CSV
# ********************
# ✅ Inserted 11454 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202209010000.CSV
# ✅ Inserted 3699239 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202209010000.CSV
# ********************
# ✅ Inserted 11460 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202210010000.CSV
# ✅ Inserted 3832653 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202210010000.CSV
# ********************
# ✅ Inserted 11462 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202211010000.CSV
# ✅ Inserted 3715219 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202211010000.CSV
# ********************
# ✅ Inserted 11474 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202212010000.CSV
# ✅ Inserted 3866438 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202212010000.CSV
# ********************
# ✅ Inserted 11477 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202301010000.CSV
# ✅ Inserted 3882451 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202301010000.CSV
# ********************
# ✅ Inserted 11484 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202302010000.CSV
# ✅ Inserted 3520108 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202302010000.CSV
# ********************
# ✅ Inserted 11493 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202303010000.CSV
# ✅ Inserted 3936156 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202303010000.CSV
# ********************
# ✅ Inserted 11501 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202304010000.CSV
# ✅ Inserted 3839421 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202304010000.CSV
# ********************
# ✅ Inserted 11509 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202305010000.CSV
# ✅ Inserted 3974288 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202305010000.CSV
# ********************
# ✅ Inserted 12157 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202306010000.CSV
# ✅ Inserted 3893472 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202306010000.CSV
# ********************
# ✅ Inserted 12164 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202307010000.CSV
# ✅ Inserted 4047628 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202307010000.CSV
# ********************
# ✅ Inserted 12166 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202308010000.CSV
# ✅ Inserted 4099796 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202308010000.CSV
# ********************
# ✅ Inserted 12175 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202309010000.CSV
# ✅ Inserted 3969449 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202309010000.CSV
# ********************
# ✅ Inserted 12183 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202310010000.CSV
# ✅ Inserted 4123346 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202310010000.CSV
# ********************
# ✅ Inserted 12204 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202311010000.CSV
# ✅ Inserted 4004601 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202311010000.CSV
# ********************
# ✅ Inserted 12209 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202312010000.CSV
# ✅ Inserted 4191392 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202312010000.CSV
# ********************
# ✅ Inserted 12212 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202401010000.CSV
# ✅ Inserted 4193480 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202401010000.CSV
# ********************
# ✅ Inserted 12221 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202402010000.CSV
# ✅ Inserted 3923682 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202402010000.CSV
# ********************
# ✅ Inserted 12229 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202403010000.CSV
# ✅ Inserted 4188581 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202403010000.CSV
# ********************
# ✅ Inserted 12236 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202404010000.CSV
# ✅ Inserted 4052269 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202404010000.CSV
# ********************
# ✅ Inserted 12561 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202405010000.CSV
# ✅ Inserted 4202535 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202405010000.CSV
# ********************
# ✅ Inserted 13220 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202406010000.CSV
# ✅ Inserted 4103639 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202406010000.CSV
# ********************
# ✅ Inserted 13229 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_DVD_DUDETAILSUMMARY_202407010000.CSV
# ✅ Inserted 4281109 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_DVD_DISPATCH_UNIT_SCADA_202407010000.CSV
# ********************
# ✅ Inserted 13246 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#202408010000.CSV
# ✅ Inserted 4136178 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#202408010000.CSV
# ********************
# ✅ Inserted 13260 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#202409010000.CSV
# ✅ Inserted 4034259 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#202409010000.CSV
# ********************
# ✅ Inserted 13269 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#202410010000.CSV
# ✅ Inserted 4082274 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#202410010000.CSV
# ********************
# ✅ Inserted 13276 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#202411010000.CSV
# /var/folders/b6/bmslj24d11n41826_8m7yb400000gn/T/ipykernel_4162/2313067228.py:32: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scada = pd.read_csv(scada_csv, skiprows=1)  # Skip first row
# ✅ Inserted 3902492 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#202411010000.CSV
# ********************
# ✅ Inserted 13287 rows into DUDETAILSUMMARY from extracted_csv/PUBLIC_ARCHIVE#DUDETAILSUMMARY#FILE01#202412010000.CSV
# ✅ Inserted 4048391 rows into DISPATCH_UNIT_SCADA from extracted_csv/PUBLIC_ARCHIVE#DISPATCH_UNIT_SCADA#FILE01#202412010000.CSV
# ********************
# 🎉 Data import completed!
